# %%
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
np.random.seed(1)

# %%
x=np.random.randint(0,5,100)

# %%
y=x+np.random.normal(0,5,100)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.28342408],
#        [0.28342408, 1.        ]])

# %%
plt.scatter(x,y)
plt.show()

# %%
data=pd.read_csv("Dataset.csv")
data
# Out:
#       Gender    Height      Weight  Index
# 0       Male  1.875714  109.721205      4
# 1       Male  1.747060   73.622879      1
# 2       Male  1.882397   96.497744      2
# 3       Male  1.821967   99.809704      3
# 4       Male  1.774998   93.598806      3
# ...      ...       ...         ...    ...
# 9995  Female  1.680785   62.041283      1
# 9996  Female  1.703506   77.504471      4
# 9997  Female  1.622247   58.275494      2
# 9998  Female  1.753470   74.322315      3
# 9999  Female  1.573384   51.550427      1
#
# [10000 rows x 4 columns]

# %%
df=pd.DataFrame(data)

# %%
wei=df['Weight']

# %%
hei=df['Height']

# %%
np.corrcoef(wei,hei)
# Out:
# array([[1.       , 0.9247563],
#        [0.9247563, 1.       ]])

# %%
plt.scatter(wei,hei)
plt.show()

# %%
df=pd.DataFrame({'a':np.random.randint(0,20,1000)})

# %%
#positive correlation with a
df['b']=df['a']+np.random.randint(0,10,1000)

# %%
#negative correlation with a
df['c']=df['a']+np.random.randint(0,5,1000)

# %%
#no correlation with a
df['d']=df['a']+np.random.randint(0,20,1000)

# %%
#show correlation
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.899200  0.902180  0.702727
# b  0.899200  1.000000  0.819446  0.625300
# c  0.902180  0.819446  1.000000  0.645524
# d  0.702727  0.625300  0.645524  1.000000

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df)
plt.show()

# %%
sns.pairplot(df)
